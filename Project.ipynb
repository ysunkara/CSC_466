# %% [markdown]
# CSC_466 Project
# Ash Parasa, William Huang, Yogitha Sunkara

# %%
from pathlib import Path
home = str(Path.home()) # all other paths are relative to this path. change to something else if this is not the case on your system

# %%
import pandas as pd

# %%
df_symptoms = pd.read_csv(f"{home}/CSC_466/2021VAERSSYMPTOMS.csv")

# %%
df_vax = pd.read_csv(f"{home}/CSC_466/2021VAERSVAX.csv")

# %%
df_data = pd.read_csv(f"{home}/CSC_466/2021VAERSDATA.csv", encoding="latin1")

# %%
df_half = pd.merge(df_data, df_symptoms)
df_covid = pd.merge(df_half, df_vax)

# %%
df_covid
# Out:
#        VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0        916600  01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 1        916601  01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 2        916602  01/01/2021    WA     23.0     23.0      NaN   F      NaN
# 3        916603  01/01/2021    WA     58.0     58.0      NaN   F      NaN
# 4        916604  01/01/2021    TX     47.0     47.0      NaN   F      NaN
# ...         ...         ...   ...      ...      ...      ...  ..      ...
# 49016   1113920  03/19/2021    PA     83.0      NaN      NaN   F      NaN
# 49017   1113920  03/19/2021    PA     83.0      NaN      NaN   F      NaN
# 49018   1113963  03/19/2021    MS     59.0      NaN      NaN   F      NaN
# 49019   1115045  03/19/2021    AZ     57.0      NaN      NaN   M      NaN
# 49020   1115348  03/19/2021    NC      NaN     85.0      NaN   F      NaN
#
#                                             SYMPTOM_TEXT DIED  ...  \
# 0      Right side of epiglottis swelled up and hinder...  NaN  ...
# 1      Approximately 30 min post vaccination administ...  NaN  ...
# 2      About 15 minutes after receiving the vaccine, ...  NaN  ...
# 3      extreme fatigue, dizziness,. could not lift my...  NaN  ...
# 4      Injection site swelling, redness, warm to the ...  NaN  ...
# ...                                                  ...  ...  ...
# 49016  positive COVID-19 test with no symptoms; Asymp...  NaN  ...
# 49017  positive COVID-19 test with no symptoms; Asymp...  NaN  ...
# 49018  HLH (hemophagocyticlymphohistiocytosis); This ...    Y  ...
# 49019  Death; A spontaneous report was received from ...    Y  ...
# 49020  death; A spontaneous report was received from ...    Y  ...
#
#       SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5 VAX_TYPE         VAX_MANU  \
# 0                 NaN      NaN             NaN  COVID19          MODERNA
# 1                 NaN      NaN             NaN  COVID19          MODERNA
# 2                23.1      NaN             NaN  COVID19  PFIZER\BIONTECH
# 3                 NaN      NaN             NaN  COVID19          MODERNA
# 4                23.1      NaN             NaN  COVID19          MODERNA
# ...               ...      ...             ...      ...              ...
# 49016            23.1  Pyrexia            23.1  COVID19  PFIZER\BIONTECH
# 49017             NaN      NaN             NaN  COVID19  PFIZER\BIONTECH
# 49018             NaN      NaN             NaN  COVID19  PFIZER\BIONTECH
# 49019             NaN      NaN             NaN  COVID19          MODERNA
# 49020             NaN      NaN             NaN  COVID19          MODERNA
#
#        VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 0      037K20A               1        IM       LA
# 1      025L20A               1        IM       RA
# 2       EL1284               1        IM       LA
# 3      unknown             UNK       NaN      NaN
# 4          NaN               1        IM       LA
# ...        ...             ...       ...      ...
# 49016  Unknown               1       NaN      NaN
# 49017  Unknown               1       NaN      NaN
# 49018   EL9264               2       NaN      NaN
# 49019      NaN               2        OT      NaN
# 49020  026A21A               1        OT       LA
#
#                                   VAX_NAME
# 0              COVID19 (COVID19 (MODERNA))
# 1              COVID19 (COVID19 (MODERNA))
# 2      COVID19 (COVID19 (PFIZER-BIONTECH))
# 3              COVID19 (COVID19 (MODERNA))
# 4              COVID19 (COVID19 (MODERNA))
# ...                                    ...
# 49016  COVID19 (COVID19 (PFIZER-BIONTECH))
# 49017  COVID19 (COVID19 (PFIZER-BIONTECH))
# 49018  COVID19 (COVID19 (PFIZER-BIONTECH))
# 49019          COVID19 (COVID19 (MODERNA))
# 49020          COVID19 (COVID19 (MODERNA))
#
# [49021 rows x 52 columns]
